# %% [markdown]
# # IBM HR Analytics Employee Attrition & Performance
#
# Descubra los factores que conducen a la deserción de los empleados y explore preguntas como "muéstre un desglose de la distancia desde el hogar al trabajo por función laboral y deserción" o "compare el ingreso mensual promedio por educación y deserción". Este es un conjunto de datos ficticios creado por científicos de datos de IBM.
#
# Principales variables:
#
# |º|Education| EnvironmentSatisfaction |JobInvolvement|PerformanceRating|RelationshipSatisfaction|WorkLifeBalance
# |:--:|:------:|:------:|:------:|:------:|:------:|:------:|
# |1|'Below College'| 'Low'|'Low'|'Low'|'Low'|'Bad'|
# |2|'College'|'Medium'|'Medium'|'Good'|'Medium'|'Good'|
# |3|'Bachelor'|'High'|'High'|'Excellent'|'High'| 'Better'|
# |4|'Master'|'Very High'|'Very High'|'Outstanding'|'Very High'|'Best'|
# |5|'Doctor'||

# %% [markdown]
# ### Importo librerias

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl            # Matplotlib
import matplotlib.pyplot as plt     # El modulo Pyplot de Matplotlib
import seaborn as sns               # Seaborn

mpl.style.use('bmh')    # Establecemos un nuevo estilo

from prettytable import PrettyTable

# %% [markdown]
# ## 1) DATA PROCESS & EXPLORATORY DATA ANALYSIS (EDA)¶

# %%
# Cargamos el dataset
df = pd.read_csv('Datos/WA_Fn-UseC-HR-Employee-Attrition.csv')
pd.set_option('max_columns', None)
df.sample(6)
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 630    22        No      Travel_Rarely       1230  Research & Development
# 423    30        No         Non-Travel       1398                   Sales
# 134    26        No      Travel_Rarely       1355         Human Resources
# 366    41       Yes  Travel_Frequently        143                   Sales
# 657    29        No      Travel_Rarely       1086  Research & Development
# 1304   40        No      Travel_Rarely        750  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 630                  1          2  Life Sciences              1
# 423                 22          4          Other              1
# 134                 25          1  Life Sciences              1
# 366                  4          3      Marketing              1
# 657                  7          1        Medical              1
# 1304                12          3  Life Sciences              1
#
#       EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  \
# 630              872                        4    Male          33
# 423              567                        3  Female          69
# 134              177                        3  Female          61
# 366              488                        1    Male          56
# 657              912                        1  Female          62
# 1304            1829                        2  Female          47
#
#       JobInvolvement  JobLevel                    JobRole  JobSatisfaction  \
# 630                2         2     Manufacturing Director                4
# 423                3         3            Sales Executive                1
# 134                3         1            Human Resources                3
# 366                3         2            Sales Executive                2
# 657                2         1      Laboratory Technician                4
# 1304               3         2  Healthcare Representative                1
#
#      MaritalStatus  MonthlyIncome  MonthlyRate  NumCompaniesWorked Over18  \
# 630        Married           4775        19146                   6      Y
# 423        Married           8412         2890                   0      Y
# 134        Married           2942         8916                   1      Y
# 366         Single           9355         9558                   1      Y
# 657       Divorced           2532         6054                   6      Y
# 1304      Divorced           4448        10748                   2      Y
#
#      OverTime  PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  \
# 630        No                 22                  4                         1
# 423        No                 11                  3                         3
# 134        No                 23                  4                         4
# 366        No                 18                  3                         3
# 657        No                 14                  3                         3
# 1304       No                 12                  3                         2
#
#       StandardHours  StockOptionLevel  TotalWorkingYears  \
# 630              80                 2                  4
# 423              80                 0                 10
# 134              80                 1                  8
# 366              80                 0                  8
# 657              80                 3                  8
# 1304             80                 1                 15
#
#       TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# 630                       2                1               2
# 423                       3                3               9
# 134                       3                3               8
# 366                       5                3               8
# 657                       5                3               4
# 1304                      3                3               7
#
#       YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 630                    2                        2                     2
# 423                    8                        7                     8
# 134                    7                        5                     7
# 366                    7                        7                     7
# 657                    3                        0                     3
# 1304                   4                        7                     7

# %%
# Generamos una descripcion de cada campo
def df_explore(df):
    #Description table of the main characteristics of each column from a dataset
    print( 'Shape: ', df.shape)
    
    t = PrettyTable(['Column', 
                     'Type',
                     'Non-Null',
                     'Nulls',
                     'Unique',
                     'Example',
                    ])
    
    for c in df.columns:
        t.add_row([c,
                   df[c].dtype,
                   len(df[c])-np.sum(df[c].isna()),
                   np.sum(df[c].isna()),
                   np.count_nonzero(df[c].unique()),
                   df[~df[c].isnull()][c].iloc[0],
                  ]) 
    print(t)
    print()
    return

df_explore(df)
# Out:
# Shape:  (1470, 35)
# +--------------------------+--------+----------+-------+--------+-----------------+
# |          Column          |  Type  | Non-Null | Nulls | Unique |     Example     |
# +--------------------------+--------+----------+-------+--------+-----------------+
# |           Age            | int64  |   1470   |   0   |   43   |        41       |
# |        Attrition         | object |   1470   |   0   |   2    |       Yes       |
# |      BusinessTravel      | object |   1470   |   0   |   3    |  Travel_Rarely  |
# |        DailyRate         | int64  |   1470   |   0   |  886   |       1102      |
# |        Department        | object |   1470   |   0   |   3    |      Sales      |
# |     DistanceFromHome     | int64  |   1470   |   0   |   29   |        1        |
# |        Education         | int64  |   1470   |   0   |   5    |        2        |
# |      EducationField      | object |   1470   |   0   |   6    |  Life Sciences  |
# |      EmployeeCount       | int64  |   1470   |   0   |   1    |        1        |
# |      EmployeeNumber      | int64  |   1470   |   0   |  1470  |        1        |
# | EnvironmentSatisfaction  | int64  |   1470   |   0   |   4    |        2        |
# |          Gender          | object |   1470   |   0   |   2    |      Female     |
# |        HourlyRate        | int64  |   1470   |   0   |   71   |        94       |
# |      JobInvolvement      | int64  |   1470   |   0   |   4    |        3        |
# |         JobLevel         | int64  |   1470   |   0   |   5    |        2        |
# |         JobRole          | object |   1470   |   0   |   9    | Sales Executive |
# |     JobSatisfaction      | int64  |   1470   |   0   |   4    |        4        |
# |      MaritalStatus       | object |   1470   |   0   |   3    |      Single     |
# |      MonthlyIncome       | int64  |   1470   |   0   |  1349  |       5993      |
# |       MonthlyRate        | int64  |   1470   |   0   |  1427  |      19479      |
# |    NumCompaniesWorked    | int64  |   1470   |   0   |   9    |        8        |
# |          Over18          | object |   1470   |   0   |   1    |        Y        |
# |         OverTime         | object |   1470   |   0   |   2    |       Yes       |
# |    PercentSalaryHike     | int64  |   1470   |   0   |   15   |        11       |
# |    PerformanceRating     | int64  |   1470   |   0   |   2    |        3        |
# | RelationshipSatisfaction | int64  |   1470   |   0   |   4    |        1        |
# |      StandardHours       | int64  |   1470   |   0   |   1    |        80       |
# |     StockOptionLevel     | int64  |   1470   |   0   |   3    |        0        |
# |    TotalWorkingYears     | int64  |   1470   |   0   |   39   |        8        |
# |  TrainingTimesLastYear   | int64  |   1470   |   0   |   6    |        0        |
# |     WorkLifeBalance      | int64  |   1470   |   0   |   4    |        1        |
# |      YearsAtCompany      | int64  |   1470   |   0   |   36   |        6        |
# |    YearsInCurrentRole    | int64  |   1470   |   0   |   18   |        4        |
# | YearsSinceLastPromotion  | int64  |   1470   |   0   |   15   |        0        |
# |   YearsWithCurrManager   | int64  |   1470   |   0   |   17   |        5        |
# +--------------------------+--------+----------+-------+--------+-----------------+

# %% [markdown]
# **OBS:** No hay valores nulos
#
# ### 1.1: Verifico los valore únicos de algunas variables

# %%
# Print unique values for categorical variables:
print('Attrition: ', df['Attrition'].unique(), "\n")
print('BusinessTravel: ', df['BusinessTravel'].unique(), "\n")
print('Department:', df['Department'].unique(), "\n")
print('Education Field:', df['EducationField'].unique(), "\n")          
print('Gender:', df['Gender'].unique(), "\n")
print('JobRole:', df['JobRole'].unique(), "\n")
print('MaritalStatus:', df['MaritalStatus'].unique(), "\n")
print('Over18:', df['Over18'].unique(), "\n")
print('OverTime:', df['OverTime'].unique(), "\n")
# Out:
# Attrition:  ['Yes' 'No']
#
# BusinessTravel:  ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
#
# Department: ['Sales' 'Research & Development' 'Human Resources']
#
# Education Field: ['Life Sciences' 'Other' 'Medical' 'Marketing' 'Technical Degree'
#  'Human Resources']
#
# Gender: ['Female' 'Male']
#
# JobRole: ['Sales Executive' 'Research Scientist' 'Laboratory Technician'
#  'Manufacturing Director' 'Healthcare Representative' 'Manager'
#  'Sales Representative' 'Research Director' 'Human Resources']
#
# MaritalStatus: ['Single' 'Married' 'Divorced']
#
# Over18: ['Y']
#
# OverTime: ['Yes' 'No']

# %%
# Generamos una pretty tabla con valores unicos

def df_unique_val_col(df, col_list = [] ):
    #Description table of the main characteristics of each column from a dataset
    
    #Cuento la máxima cantidad de valores unicos que tienen las variables/columnas
    cant_table_col = 0
    for i in col_list:
        l = len(df[i].unique())
        if cant_table_col < l:
            cant_table_col = l
    
    # Creo la lista de campos "value_x" para armar la prettytable
    A = ['Columna']
    for i in range(9):
        A.append('Value_'+str(i+1))
        
    B = []
    for c in df[L]:
        B.append(df[c].unique())
        #print(B)
        B = []
        
        dg = pd.DataFrame(index = df[col_list].columns,
                          columns = A)    
        
        for c in dg.index:
            dg[c] = 


        
    print()
    return dg

# %%
# lista de prueba
L = ['Attrition','BusinessTravel','Department','EducationField','Gender','JobRole','MaritalStatus','Over18','OverTime']
len(L)
# Out:
# 9

# %%
df_unique_val_col(df,L)
# Out:
#                Columna Value_1 Value_2 Value_3 Value_4 Value_5 Value_6  \
# Attrition          NaN     NaN     NaN     NaN     NaN     NaN     NaN
# BusinessTravel     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# Department         NaN     NaN     NaN     NaN     NaN     NaN     NaN
# EducationField     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# Gender             NaN     NaN     NaN     NaN     NaN     NaN     NaN
# JobRole            NaN     NaN     NaN     NaN     NaN     NaN     NaN
# MaritalStatus      NaN     NaN     NaN     NaN     NaN     NaN     NaN
# Over18             NaN     NaN     NaN     NaN     NaN     NaN     NaN
# OverTime           NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#                Value_7 Value_8 Value_9
# Attrition          NaN     NaN     NaN
# BusinessTravel     NaN     NaN     NaN
# Department         NaN     NaN     NaN
# EducationField     NaN     NaN     NaN
# Gender             NaN     NaN     NaN
# JobRole            NaN     NaN     NaN
# MaritalStatus      NaN     NaN     NaN
# Over18             NaN     NaN     NaN
# OverTime           NaN     NaN     NaN

# %%
# probando
A = []
for c in df[L]:
    A.append(df[c].unique())
    print(A)
    A = []
# Out:
# [array(['Yes', 'No'], dtype=object)]
# [array(['Travel_Rarely', 'Travel_Frequently', 'Non-Travel'], dtype=object)]
# [array(['Sales', 'Research & Development', 'Human Resources'], dtype=object)]
# [array(['Life Sciences', 'Other', 'Medical', 'Marketing',
#        'Technical Degree', 'Human Resources'], dtype=object)]
# [array(['Female', 'Male'], dtype=object)]
# [array(['Sales Executive', 'Research Scientist', 'Laboratory Technician',
#        'Manufacturing Director', 'Healthcare Representative', 'Manager',
#        'Sales Representative', 'Research Director', 'Human Resources'],
#       dtype=object)]
# [array(['Single', 'Married', 'Divorced'], dtype=object)]
# [array(['Y'], dtype=object)]
# [array(['Yes', 'No'], dtype=object)]

# %%
A = []
for i in range(9):
    A.append('Value_'+str(i+1))
        
dg = pd.DataFrame( index = A, columns = df[L].columns)

dg
# Out:
#         Attrition BusinessTravel Department EducationField Gender JobRole  \
# Value_1       NaN            NaN        NaN            NaN    NaN     NaN
# Value_2       NaN            NaN        NaN            NaN    NaN     NaN
# Value_3       NaN            NaN        NaN            NaN    NaN     NaN
# Value_4       NaN            NaN        NaN            NaN    NaN     NaN
# Value_5       NaN            NaN        NaN            NaN    NaN     NaN
# Value_6       NaN            NaN        NaN            NaN    NaN     NaN
# Value_7       NaN            NaN        NaN            NaN    NaN     NaN
# Value_8       NaN            NaN        NaN            NaN    NaN     NaN
# Value_9       NaN            NaN        NaN            NaN    NaN     NaN
#
#         MaritalStatus Over18 OverTime
# Value_1           NaN    NaN      NaN
# Value_2           NaN    NaN      NaN
# Value_3           NaN    NaN      NaN
# Value_4           NaN    NaN      NaN
# Value_5           NaN    NaN      NaN
# Value_6           NaN    NaN      NaN
# Value_7           NaN    NaN      NaN
# Value_8           NaN    NaN      NaN
# Value_9           NaN    NaN      NaN

# %%
for i in L:
    
    uni = df[i].unique()
    l = len(uni)
    
    for j in range(l):
        dg[i][j] = uni[j]
dg.replace(np.nan, 0)       
dg
# Out:
#         Attrition     BusinessTravel              Department  \
# Value_1       Yes      Travel_Rarely                   Sales
# Value_2        No  Travel_Frequently  Research & Development
# Value_3       NaN         Non-Travel         Human Resources
# Value_4       NaN                NaN                     NaN
# Value_5       NaN                NaN                     NaN
# Value_6       NaN                NaN                     NaN
# Value_7       NaN                NaN                     NaN
# Value_8       NaN                NaN                     NaN
# Value_9       NaN                NaN                     NaN
#
#            EducationField  Gender                    JobRole MaritalStatus  \
# Value_1     Life Sciences  Female            Sales Executive        Single
# Value_2             Other    Male         Research Scientist       Married
# Value_3           Medical     NaN      Laboratory Technician      Divorced
# Value_4         Marketing     NaN     Manufacturing Director           NaN
# Value_5  Technical Degree     NaN  Healthcare Representative           NaN
# Value_6   Human Resources     NaN                    Manager           NaN
# Value_7               NaN     NaN       Sales Representative           NaN
# Value_8               NaN     NaN          Research Director           NaN
# Value_9               NaN     NaN            Human Resources           NaN
#
#         Over18 OverTime
# Value_1      Y      Yes
# Value_2    NaN       No
# Value_3    NaN      NaN
# Value_4    NaN      NaN
# Value_5    NaN      NaN
# Value_6    NaN      NaN
# Value_7    NaN      NaN
# Value_8    NaN      NaN
# Value_9    NaN      NaN

# %%
dg.Attrition.loc['Value_6']
# Out:
# nan
